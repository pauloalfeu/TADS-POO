// %% [markdown]
// # Atv01

// %% [markdown]
// # Exiba a mensagem "Disciplina POO" usando a estrutura miníma para um código em Java.

// %%
// Public class Main {
// public static void main(String[] args) {
    System.out.printf("Disciplina POO");
// }
//}
// Out:
// Disciplina POO
// null
